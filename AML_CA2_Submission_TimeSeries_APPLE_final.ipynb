# %% [markdown]
# # IT8302 Applied Machine Learning - CA2 Submission - Time Series Forecasting Models
# ### Submitted By: Lo Ka Fai
# ### Student ID: 7304896V
# ### Submission Date: 16 Feb 2025

# %% [markdown]
# # PART B: STOCK PRICE FORECASTING
# ## Objective:
# ## In this segment, we will analyse 3 different stocks (Apple, Amazon, DBS) using Time Series forecasting models to train and predict the future stock price for the next 60 days.

# %% [markdown]
# ## Stock Dataset : The stock dataset is given (CA2-Stock-Price-Data.csv).
# ## The stock dataset contains 5 years (2018-2023) of close price data for stock Apple, Amazon and DBS.

# %% [markdown]
# ## 1. Import Libraries

# %%
# Check if statemodels has been installed
# !pip show statsmodels
# Out:
# Name: statsmodels
# Version: 0.14.2
# Summary: Statistical computations and models for Python
# Home-page: https://www.statsmodels.org/
# Author:
# Author-email:
# License: BSD License
# Location: C:\Users\lokf2\anaconda3\Lib\site-packages
# Requires: numpy, packaging, pandas, patsy, scipy
# Required-by:

# %%
# For automatic ARIMA model selection in time series forecasting.
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\lokf2\anaconda3\lib\site-packages (from pmdarima) (1.4.2)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima)
#   Downloading Cython-3.0.11-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\lokf2\anaconda3\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\lokf2\anaconda3\lib\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\lokf2\anaconda3\lib\site-packages (from pmdarima) (1.3.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\lokf2\anaconda3\lib\site-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\lokf2\anaconda3\lib\site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in c:\users\lokf2\anaconda3\lib\site-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\lokf2\anaconda3\lib\site-packages (from pmdarima) (75.1.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\lokf2\anaconda3\lib\site-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lokf2\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lokf2\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lokf2\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lokf2\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\lokf2\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in c:\users\lokf2\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading pmdarima-2.0.4-cp312-cp312-win_amd64.whl (625 kB)
#    ---------------------------------------- 0.0/625.1 kB ? eta -:--:--
#    --------------------------------------- 625.1/625.1 kB 11.7 MB/s eta 0:00:00
# Downloading Cython-3.0.11-cp312-cp312-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------------------------------ --------- 2.1/2.8 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 10.8 MB/s eta 0:00:00
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.0.11 pmdarima-2.0.4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.tools import diff
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_percentage_error
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Import Dataset and Exploratory Data Analysis

# %%
df = pd.read_csv("CA2-Stock-Price-Data.csv")
df
# Out:
#            Date       Apple      Amazon        DBS
# 0     10/1/2018   56.814999  100.218002  25.969999
# 1     10/2/2018   57.320000   98.565498  25.629999
# 2     10/3/2018   58.017502   97.638000  25.950001
# 3     10/4/2018   56.997501   95.471001  25.760000
# 4     10/5/2018   56.072498   94.482498  25.770000
# ...         ...         ...         ...        ...
# 1252  9/22/2023  174.789993  129.119995  33.250000
# 1253  9/25/2023  176.080002  131.270004  33.450001
# 1254  9/26/2023  171.960007  125.980003  33.509998
# 1255  9/27/2023  170.429993  125.980003  33.430000
# 1256  9/28/2023  170.690002  125.980003  33.500000
#
# [1257 rows x 4 columns]

# %% [markdown]
# ### 2.1 Check on dataset

# %% [markdown]
# ### Create function "eda" to automate EDA checks

# %%
def eda(df):
    
    print("Perform Exploratory Data Analysis (EDA) on dataset")
    
    print("\n*** First 5 Rows ***")
    display(df.head())

    print("\n*** Last 5 Rows ***")
    display(df.tail())
    
    print("\n*** Shape of Dataset ***")
    print(df.shape)
    
    print("\n*** Info ***")
    print(df.info())

    print("\n*** Missing Values ***")
    missing_values = df.isnull().sum()
    print(missing_values)
    
    print("\n*** Statistical Summary ***")
    display(df.describe())
    
    print("\n*** Histograms ***")
    df.hist(figsize=(12,10), bins=30, edgecolor='k')
    plt.tight_layout()
    plt.show()

# %%
eda(df)
# Out:
# Perform Exploratory Data Analysis (EDA) on dataset
#
# *** First 5 Rows ***
#         Date      Apple      Amazon        DBS
# 0  10/1/2018  56.814999  100.218002  25.969999
# 1  10/2/2018  57.320000   98.565498  25.629999
# 2  10/3/2018  58.017502   97.638000  25.950001
# 3  10/4/2018  56.997501   95.471001  25.760000
# 4  10/5/2018  56.072498   94.482498  25.770000
# *** Last 5 Rows ***
#            Date       Apple      Amazon        DBS
# 1252  9/22/2023  174.789993  129.119995  33.250000
# 1253  9/25/2023  176.080002  131.270004  33.450001
# 1254  9/26/2023  171.960007  125.980003  33.509998
# 1255  9/27/2023  170.429993  125.980003  33.430000
# 1256  9/28/2023  170.690002  125.980003  33.500000
# *** Shape of Dataset ***
# (1257, 4)
#
# *** Info ***
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1257 non-null   object
#  1   Apple   1257 non-null   float64
#  2   Amazon  1257 non-null   float64
#  3   DBS     1257 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 39.4+ KB
# None
#
# *** Missing Values ***
# Date      0
# Apple     0
# Amazon    0
# DBS       0
# dtype: int64
#
# *** Statistical Summary ***
#              Apple       Amazon          DBS
# count  1257.000000  1257.000000  1257.000000
# mean    116.168385   124.791237    28.185863
# std      46.945568    32.495925     4.738732
# min      35.547501    67.197998    16.879999
# 25%      66.592499    93.489998    24.879999
# 50%     129.610001   120.970001    28.650000
# 75%     152.589996   158.100494    32.480000
# max     196.449997   186.570496    37.250000
# *** Histograms ***

# %% [markdown]
# ### No missing data, the data is clean and cleaning is not required.

# %% [markdown]
# ## 3. Preprocess Data

# %% [markdown]
# ### 3.1 Create 3 individual stock dataset for analysis

# %%
# Create separate DataFrames for each stock
df_aapl = df[['Date', 'Apple']].copy()
df_amzn = df[['Date', 'Amazon']].copy()
df_dbs = df[['Date', 'DBS']].copy()

# Show the first 5 rows of each DataFrame
print("Apple Stock Data:")
print(df_aapl.head())
print("\nAmazon Stock Data:")
print(df_amzn.head())
print("\nDBS Stock Data:")
print(df_dbs.head())
# Out:
# Apple Stock Data:
#         Date      Apple
# 0  10/1/2018  56.814999
# 1  10/2/2018  57.320000
# 2  10/3/2018  58.017502
# 3  10/4/2018  56.997501
# 4  10/5/2018  56.072498
#
# Amazon Stock Data:
#         Date      Amazon
# 0  10/1/2018  100.218002
# 1  10/2/2018   98.565498
# 2  10/3/2018   97.638000
# 3  10/4/2018   95.471001
# 4  10/5/2018   94.482498
#
# DBS Stock Data:
#         Date        DBS
# 0  10/1/2018  25.969999
# 1  10/2/2018  25.629999
# 2  10/3/2018  25.950001
# 3  10/4/2018  25.760000
# 4  10/5/2018  25.770000

# %% [markdown]
# ### 3.2 APPL - APPLE stock

# %%
df_aapl.head()
# Out:
#         Date      Apple
# 0  10/1/2018  56.814999
# 1  10/2/2018  57.320000
# 2  10/3/2018  58.017502
# 3  10/4/2018  56.997501
# 4  10/5/2018  56.072498

# %% [markdown]
# ### 3.2.1 Convert Date column to datetime format and set Date column as the index for time series analysis

# %%
df_aapl['Date'] = pd.to_datetime(df_aapl['Date'])
df_aapl.set_index("Date", inplace=True)

# %%
df_aapl.head()
# Out:
#                 Apple
# Date
# 2018-10-01  56.814999
# 2018-10-02  57.320000
# 2018-10-03  58.017502
# 2018-10-04  56.997501
# 2018-10-05  56.072498

# %% [markdown]
# ### 3.2.2 Check Stationarity

# %% [markdown]
# ### Visual Check AAPL stock price chart

# %%
plt.figure(figsize=(9, 6))
df_aapl.plot()
plt.title('APPLE Stock')
plt.show()

# %% [markdown]
# ### AAPL price on the chart is trending and does not fulfill any of the stationary series properties (mean, variance, covariance), the data is not stationary.

# %% [markdown]
# ### Check with Histogram

# %%
# Create the histogram for the 'Apple' stock data
plt.figure(figsize=(9, 6))
df_aapl['Apple'].plot(kind='hist', bins=50)
plt.title('APPLE Stock Histogram')
plt.xlabel('Stock Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### It is not a typical bell curve, the data is not stationary.

# %% [markdown]
# ### Check with Augmented Dickey Fuller (ADF) test

# %%
result = adfuller(df_aapl['Apple'])

# Output the results 
print(f'AAPL No of Observations: {result[3]:}')
print(f'AAPL dataset p-value: {result[1]:.4f}')
# Out:
# AAPL No of Observations: 1256
# AAPL dataset p-value: 0.7651

# %% [markdown]
# ### P-value > 0.05: Fail to reject the null hypothesis (H0), the data is non-stationary.
# ### No of Observations means the number valid data points were used in the actual statistical test after accounting for the lags. Higher the numbers of observations used in the test, the more reliable of the test.

# %% [markdown]
# ### 3.2.3 Differencing (Make the data stationary)

# %%
# Perform differencing operations
df_aapl_diff = diff(df_aapl['Apple'], k_diff=1)  # First differencing
df_aapl_diff2 = diff(df_aapl_diff, k_diff=1)  # Second differencing

# Apply ADF test to the original and differenced series
result1 = adfuller(df_aapl['Apple'])  # Original series
result2 = adfuller(df_aapl_diff.dropna())  # Differenced once (drop NaN)
result3 = adfuller(df_aapl_diff2.dropna())  # Differenced twice (drop NaN)

# Output the results
print('AAPL before differencing p-value: %f' % result1[1])
print('AAPL after differencing p-value: %f' % result2[1])
print('AAPL after differencing twice p-value: %f' % result3[1])

print("\n")
      
# Plot the time series before and after differencing
fig, ax = plt.subplots(1, 3, figsize=(16, 4))

df_aapl['Apple'].plot(ax=ax[0])
df_aapl_diff.plot(ax=ax[1])
df_aapl_diff2.plot(ax=ax[2])

ax[0].set_title('Time Series Before Differencing')
ax[1].set_title('Time Series After Differencing')
ax[2].set_title('Time Series After Differencing Twice')

# Add legend to each subplot
ax[0].legend()
ax[1].legend()
ax[2].legend()

plt.show()
# Out:
# AAPL before differencing p-value: 0.765069
# AAPL after differencing p-value: 0.000000
# AAPL after differencing twice p-value: 0.000000

# %% [markdown]
# ### From the above results, first differencing (p-value=0.0000) is sufficient to make the Apple time series stationary.

# %% [markdown]
# ### 3.2.4 Check Seasonality - Time Series Decomposition
# ### Identify the Time Series Components: Trend, Seasonality, Random component

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(df_aapl['Apple'], model='additive', period=24)  # Assuming monthly seasonality
result.plot()
plt.show()

# %% [markdown]
# ### From the seasonal components, the time series data has seasonality. We shall use SARIMA model for training and forecasting.

# %% [markdown]
# ### 3.2.5 ACF and PACF plot
# ### Use ACF and PACF plots to determine (p, d, q) and (P, D, Q, S)
# ### (Note: We use auto_arima for Hyperparameters Tuning later to search for the best (p, d, q) and (P, D, Q, S) instead.)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

#Plot ACF and PACF to determine appropriate ARIMA and seasonal parameters
fig, axes = plt.subplots(2, 1, figsize=(8, 10))
plot_acf(df_aapl_diff.dropna(), lags=24, ax=axes[0])   # ACF helps in determining the q parameter in ARIMA or SARIMA model
plot_pacf(df_aapl_diff.dropna(), lags=24, ax=axes[1])  # PACF helps in determining the p parameter in ARIMA or SARIMA model
axes[0].set_title('Autocorrelation Function (ACF)')
axes[1].set_title('Partial Autocorrelation Function (PACF)')

plt.show()

# %% [markdown]
# ## 4. Model Building

# %% [markdown]
# ### 4.1 Split Data (Train and Test)

# %%
# Split data into train and test (80-20 split)
train_size = int(len(df_aapl) * 0.8)
train, test = df_aapl['Apple'][:train_size], df_aapl['Apple'][train_size:]

# %%
train
# Out:
# Date
# 2018-10-01     56.814999
# 2018-10-02     57.320000
# 2018-10-03     58.017502
# 2018-10-04     56.997501
# 2018-10-05     56.072498
#                  ...
# 2022-09-21    153.720001
# 2022-09-22    152.740005
# 2022-09-23    150.429993
# 2022-09-26    150.770004
# 2022-09-27    151.759995
# Name: Apple, Length: 1005, dtype: float64

# %%
test
# Out:
# Date
# 2022-09-28    149.839996
# 2022-09-29    142.479996
# 2022-09-30    138.199997
# 2022-10-03    142.449997
# 2022-10-04    146.100006
#                  ...
# 2023-09-22    174.789993
# 2023-09-25    176.080002
# 2023-09-26    171.960007
# 2023-09-27    170.429993
# 2023-09-28    170.690002
# Name: Apple, Length: 252, dtype: float64

# %% [markdown]
# ### 4.2 Model Selection - Time Series Forecasting Model (SARIMA)

# %% [markdown]
# ### 4.2.1 Hyperparameter Tuning with auto_arima
# ### To search for the best parameters for ARIMA(p,d,q) and SARIMA(P,D,Q,s) model

# %% [markdown]
# ### Simple hyperparameter tuning

# %%
# Fit ARIMA or SARIMA model automatically
model = pm.auto_arima(df_aapl['Apple'], seasonal=True, m=24, stepwise=True, trace=True)

# Print the summary of the model
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[24] intercept   : AIC=inf, Time=3.75 sec
#  ARIMA(0,1,0)(0,0,0)[24] intercept   : AIC=5743.856, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[24] intercept   : AIC=5744.587, Time=0.40 sec
#  ARIMA(0,1,1)(0,0,1)[24] intercept   : AIC=5744.449, Time=0.49 sec
#  ARIMA(0,1,0)(0,0,0)[24]             : AIC=5743.681, Time=0.02 sec
#  ARIMA(0,1,0)(1,0,0)[24] intercept   : AIC=5744.647, Time=0.32 sec
#  ARIMA(0,1,0)(0,0,1)[24] intercept   : AIC=5744.665, Time=0.38 sec
#  ARIMA(0,1,0)(1,0,1)[24] intercept   : AIC=5746.630, Time=0.43 sec
#  ARIMA(1,1,0)(0,0,0)[24] intercept   : AIC=5743.678, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,1)[24] intercept   : AIC=5744.602, Time=0.37 sec
#  ARIMA(1,1,0)(1,0,1)[24] intercept   : AIC=5746.572, Time=0.47 sec
#  ARIMA(2,1,0)(0,0,0)[24] intercept   : AIC=5744.396, Time=0.13 sec
#  ARIMA(1,1,1)(0,0,0)[24] intercept   : AIC=5744.117, Time=0.34 sec
#  ARIMA(0,1,1)(0,0,0)[24] intercept   : AIC=5743.529, Time=0.09 sec
#  ARIMA(0,1,1)(1,0,0)[24] intercept   : AIC=5744.434, Time=0.44 sec
#  ARIMA(0,1,1)(1,0,1)[24] intercept   : AIC=5746.419, Time=0.57 sec
#  ARIMA(0,1,2)(0,0,0)[24] intercept   : AIC=5744.222, Time=0.14 sec
#  ARIMA(1,1,2)(0,0,0)[24] intercept   : AIC=5745.913, Time=0.21 sec
#  ARIMA(0,1,1)(0,0,0)[24]             : AIC=5743.527, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,0)[24]             : AIC=5744.560, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,1)[24]             : AIC=5744.577, Time=0.18 sec
#  ARIMA(0,1,1)(1,0,1)[24]             : AIC=5746.536, Time=0.28 sec
#  ARIMA(1,1,1)(0,0,0)[24]             : AIC=5744.325, Time=0.10 sec
#  ARIMA(0,1,2)(0,0,0)[24]             : AIC=5744.361, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[24]             : AIC=5743.658, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[24]             : AIC=5746.121, Time=0.08 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[24]
# Total fit time: 9.666 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1257
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -2869.764
# Date:                Mon, 10 Feb 2025   AIC                           5743.527
# Time:                        23:56:14   BIC                           5753.799
# Sample:                             0   HQIC                          5747.388
#                                - 1257
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0427      0.022     -1.977      0.048      -0.085      -0.000
# sigma2         5.6509      0.150     37.619      0.000       5.356       5.945
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               373.90
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.50   Skew:                            -0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Comprehensive hyperparameter tuning

# %%
model = pm.auto_arima(df_aapl['Apple'], 
                      # p and q values for the non-seasonal part of the model
                      start_p=1,                  # Starting value of p for ARIMA part (auto starts searching from this value)
                      start_q=1,                  # Starting value of q for ARIMA part (auto starts searching from this value)
                      max_p=2,                    # Maximum value of p for ARIMA part to search up to (controls the AR order)
                      max_q=2,                    # Maximum value of q for ARIMA part to search up to (controls the MA order)
                      
                      # P and Q values for the seasonal part of the model
                      start_P=1,                  # Starting value of P for seasonal AR part (auto starts searching from this value)
                      start_Q=1,                  # Starting value of Q for seasonal MA part (auto starts searching from this value)
                      max_P=2,                    # Maximum value of P for seasonal AR part to search up to (controls seasonal AR order)
                      max_Q=2,                    # Maximum value of Q for seasonal MA part to search up to (controls seasonal MA order)
                      
                      # Stationarity testing and differencing options
                      test="adf",                 # Statistical test to use for stationarity
                      d=1,                        # Non-seasonal differencing order (d=1 means first-order differencing to achieve stationarity)
                      D=1,                        # Seasonal differencing order (D=1 means first-order seasonal differencing to remove seasonal trends)
                      
                      # Seasonal settings
                      seasonal=True,              # Enable seasonal differencing and seasonal ARMA terms
                      m=24,                       # Seasonal period (m=24 means monthly seasonality with daily data with 24 trading days in a month)
                      
                      # Search strategy and output details
                      stepwise=True,              # Stepwise search for ARIMA parameters (tries a series of ARIMA models with different parameters and picks the best)
                      trace=True)                 # Display a trace of the search process to show progress and parameters being tried

# Print the summary of the model with the best parameters found
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,1,1)[24]             : AIC=inf, Time=10.57 sec
#  ARIMA(0,1,0)(0,1,0)[24]             : AIC=6528.361, Time=0.08 sec
#  ARIMA(1,1,0)(1,1,0)[24]             : AIC=6149.489, Time=0.60 sec
#  ARIMA(0,1,1)(0,1,1)[24]             : AIC=inf, Time=3.71 sec
#  ARIMA(1,1,0)(0,1,0)[24]             : AIC=6525.310, Time=0.16 sec
#  ARIMA(1,1,0)(2,1,0)[24]             : AIC=5995.664, Time=2.22 sec
#  ARIMA(1,1,0)(2,1,1)[24]             : AIC=inf, Time=18.54 sec
#  ARIMA(1,1,0)(1,1,1)[24]             : AIC=inf, Time=6.18 sec
#  ARIMA(0,1,0)(2,1,0)[24]             : AIC=5996.520, Time=1.39 sec
#  ARIMA(2,1,0)(2,1,0)[24]             : AIC=5995.631, Time=2.65 sec
#  ARIMA(2,1,0)(1,1,0)[24]             : AIC=6150.879, Time=0.92 sec
#  ARIMA(2,1,0)(2,1,1)[24]             : AIC=inf, Time=22.01 sec
#  ARIMA(2,1,0)(1,1,1)[24]             : AIC=inf, Time=8.76 sec
#  ARIMA(2,1,1)(2,1,0)[24]             : AIC=5997.104, Time=5.76 sec
#  ARIMA(1,1,1)(2,1,0)[24]             : AIC=5995.490, Time=6.91 sec
#  ARIMA(1,1,1)(1,1,0)[24]             : AIC=6150.531, Time=1.44 sec
#  ARIMA(1,1,1)(2,1,1)[24]             : AIC=inf, Time=18.48 sec
#  ARIMA(0,1,1)(2,1,0)[24]             : AIC=5995.413, Time=3.25 sec
#  ARIMA(0,1,1)(1,1,0)[24]             : AIC=6149.345, Time=1.35 sec
#  ARIMA(0,1,1)(2,1,1)[24]             : AIC=inf, Time=24.13 sec
#  ARIMA(0,1,1)(1,1,1)[24]             : AIC=inf, Time=10.21 sec
#  ARIMA(0,1,2)(2,1,0)[24]             : AIC=5995.393, Time=4.00 sec
#  ARIMA(0,1,2)(1,1,0)[24]             : AIC=6150.748, Time=10.47 sec
#  ARIMA(0,1,2)(2,1,1)[24]             : AIC=inf, Time=29.75 sec
#  ARIMA(0,1,2)(1,1,1)[24]             : AIC=inf, Time=14.05 sec
#  ARIMA(1,1,2)(2,1,0)[24]             : AIC=inf, Time=15.37 sec
#  ARIMA(0,1,2)(2,1,0)[24] intercept   : AIC=5997.393, Time=7.57 sec
#
# Best model:  ARIMA(0,1,2)(2,1,0)[24]
# Total fit time: 231.251 seconds
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 1257
# Model:             SARIMAX(0, 1, 2)x(2, 1, [], 24)   Log Likelihood               -2992.696
# Date:                             Mon, 10 Feb 2025   AIC                           5995.393
# Time:                                     19:45:36   BIC                           6020.975
# Sample:                                          0   HQIC                          6005.017
#                                             - 1257
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0516      0.023     -2.248      0.025      -0.097      -0.007
# ma.L2         -0.0408      0.022     -1.855      0.064      -0.084       0.002
# ar.S.L24      -0.6996      0.021    -33.374      0.000      -0.741      -0.659
# ar.S.L48      -0.3493      0.025    -13.742      0.000      -0.399      -0.300
# sigma2         7.4574      0.218     34.207      0.000       7.030       7.885
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               247.71
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.30   Skew:                             0.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### 4.3 Model Training
# ### Train the model with the best ARIMA(p, d, q) & SARIMA(P, D, Q, s) parameters

# %% [markdown]
# ### sarima_model2 - Apply best (p,d,q) and (P,D,Q,S) from Comprehensive hyperparameter tuning

# %%
# Fit SARIMA model
# s=24 for 24 days seasonality cycle 
# Best model:  ARIMA(0,1,2)(2,1,0)[24]  
# AIC                           5995.393

from statsmodels.tsa.statespace.sarimax import SARIMAX

sarima_model = SARIMAX(df_aapl['Apple'], 
                       order=(0, 1, 2),               # ARIMA(p, d, q) parameters
                       seasonal_order=(2, 1, 0, 24),  # Seasonal (P, D, Q, s)
                       enforce_stationarity=False, 
                       enforce_invertibility=False)
                       
# Fit the model
sarima_model2 = sarima_model.fit()

# Print model summary
print(sarima_model2.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Apple   No. Observations:                 1257
# Model:             SARIMAX(0, 1, 2)x(2, 1, [], 24)   Log Likelihood               -2885.781
# Date:                             Wed, 12 Feb 2025   AIC                           5781.562
# Time:                                     19:00:32   BIC                           5806.946
# Sample:                                          0   HQIC                          5791.130
#                                             - 1257
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0503      0.024     -2.130      0.033      -0.097      -0.004
# ma.L2         -0.0394      0.023     -1.740      0.082      -0.084       0.005
# ar.S.L24      -0.7092      0.022    -32.932      0.000      -0.751      -0.667
# ar.S.L48      -0.3591      0.026    -13.769      0.000      -0.410      -0.308
# sigma2         7.6657      0.231     33.222      0.000       7.213       8.118
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               212.53
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.80   Skew:                             0.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### sarima_model1 - Apply best (p,d,q) and (P,D,Q,S) from Simple hyperparameter tuning

# %%
# Best model:  ARIMA(0,1,1)(0,1,1)[24]  
# AIC                           5743.527

from statsmodels.tsa.statespace.sarimax import SARIMAX

sarima_model = SARIMAX(df_aapl['Apple'], 
                       order=(0, 1, 1),               # ARIMA(p, d, q) parameters
                       seasonal_order=(0, 1, 1, 24),  # Seasonal (P, D, Q, s)
                       enforce_stationarity=False, 
                       enforce_invertibility=False)
                       
# Fit the model
sarima_model1 = sarima_model.fit() 

# Print model summary
print(sarima_model1.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Apple   No. Observations:                 1257
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 24)   Log Likelihood               -2801.294
# Date:                            Wed, 12 Feb 2025   AIC                           5608.588
# Time:                                    19:00:51   BIC                           5623.873
# Sample:                                         0   HQIC                          5614.345
#                                            - 1257
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0425      0.023     -1.867      0.062      -0.087       0.002
# ma.S.L24      -1.0000     49.256     -0.020      0.984     -97.541      95.541
# sigma2         5.7150    281.533      0.020      0.984    -546.079     557.509
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               329.93
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.33   Skew:                            -0.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## 5. Forecasting (To forecast Apple stock price in the next 60 days)

# %% [markdown]
# ### 5.1 Apply sarima_model1 (Simple) for forecasting
# ### Best model: ARIMA(0,1,1)(0,1,1)[24]
# ### AIC: 5743.527

# %%
# Forecasting the next 60 days

forecast = sarima_model1.get_forecast(steps=60) # alpha=0.05 → 95% confidence interval (default)
forecast_index = pd.date_range(start=test.index[-1] + pd.Timedelta(days=1), periods=60, freq='D')

# Plot the predictions
plt.figure(figsize=(10, 6))
plt.plot(df_aapl.index, df_aapl['Apple'], label='Actual')
plt.plot(forecast_index, forecast.predicted_mean, label='Forecasted', color='red')
plt.fill_between(forecast_index, forecast.conf_int()['lower Apple'], forecast.conf_int()['upper Apple'], color='pink', alpha=0.3)
plt.title('SARIMA Model1 Forecast of Apple Stock Price for the next 60days')
plt.legend()
plt.show()

# %%
# Extract confidence intervals
conf_int = forecast.conf_int()

# Get the min and max forecasted price range
forecast_min = conf_int["lower Apple"].min()
forecast_max = conf_int["upper Apple"].max()

print(f"Forecasted Price Range for Next 60 Days: ${forecast_min:.2f} - ${forecast_max:.2f}")
# Out:
# Forecasted Price Range for Next 60 Days: $140.43 - $212.01

# %% [markdown]
# ### 5.2 Apply sarima_model2 (Comprehensive) for forecasting
# ### Best model: SARIMAX(0, 1, 2)x(2, 1, [], 24)
# ### AIC: 4510.466

# %%
# Forecasting the next 60 days
forecast = sarima_model2.get_forecast(steps=60)  # alpha=0.05 → 95% confidence interval (default)
forecast_index = pd.date_range(start=test.index[-1] + pd.Timedelta(days=1), periods=60, freq='D')

# Plot the predictions
plt.figure(figsize=(10, 6))
plt.plot(df_aapl.index, df_aapl['Apple'], label='Actual')
plt.plot(forecast_index, forecast.predicted_mean, label='Forecasted', color='red')
plt.fill_between(forecast_index, forecast.conf_int()['lower Apple'], forecast.conf_int()['upper Apple'], color='pink', alpha=0.3)
plt.title('SARIMA Model2 Forecast of Apple Stock Price for the next 60days')
plt.legend()
plt.show()

# %%
# Extract confidence intervals
conf_int = forecast.conf_int()

# Get the min and max forecasted price range
forecast_min = conf_int["lower Apple"].min()
forecast_max = conf_int["upper Apple"].max()

print(f"Forecasted Price Range for Next 60 Days: ${forecast_min:.2f} - ${forecast_max:.2f}")
# Out:
# Forecasted Price Range for Next 60 Days: $104.89 - $211.45

# %% [markdown]
# ### Forecasting results using the 2 SARIMA model:
#
# ### Model-1 (Simple): Predicts an upwnward trend in stock prices with some volatility, forecasting a price range between 140.43 to 212.01 over the next 60 days.
# ### Model-2 (Comprehensive): Anticipates downward trend with some volatility, projecting a price range between 104.89 to 211.45 over the same period.
# ### Both models have 95% confidence that the forecasted prices will fall within the pink zone.

# %% [markdown]
# ### 5.3 Apply arima_model for forecasting using arima results from sarima_model2
# ### Best model: SARIMAX(0, 1, 2)x(2, 1, [], 24)
# ### AIC: 4510.466

# %%
# Forecasting the next 60 days
# Fit ARIMA(0,1,2) model
arima_model = ARIMA(df_aapl['Apple'], order=(0, 1, 2)).fit()

forecast = arima_model.get_forecast(steps=60) # alpha=0.05 → 95% confidence interval (default)

forecast_index = pd.date_range(start=test.index[-1] + pd.Timedelta(days=1), periods=60, freq='D')

# Plot the predictions
plt.figure(figsize=(10, 6))
plt.plot(df_aapl.index, df_aapl['Apple'], label='Actual')
plt.plot(forecast_index, forecast.predicted_mean, label='Forecasted', color='red')
plt.fill_between(forecast_index, forecast.conf_int()['lower Apple'], forecast.conf_int()['upper Apple'], color='pink', alpha=0.3)
plt.title('ARIMA Model Forecast of Apple Stock Price for the next 60days')
plt.legend()
plt.show()

# %% [markdown]
# ### The ARIMA model forecasted a flat price movement for the stock in the next 60 trading days.
# ### ARIMA model may not be suitable for forecasting seasonal data and but it works best for non-seasonal data.

# %% [markdown]
# ### 5.4 Apply sarima_model1 to forecast the actual test data

# %% [markdown]
# ### Re-train sarima_model1 with the best model-1 parameters on Train data only

# %%
# Train SARIMA Model with train data only
sarima_model11 = SARIMAX(train, 
                        order=(3, 1, 1), 
                        seasonal_order=(3, 1, 1, 24)).fit()

# %% [markdown]
# ### Forecast and plot

# %%
# Generate forecast
forecast_result = sarima_model1.get_forecast(steps=len(test), alpha=0.05)

# Extract forecasted values and confidence intervals
fc_series = forecast_result.predicted_mean
fc_series.index = test.index  # Align forecast with actual test index
conf = forecast_result.conf_int()

lower_series = pd.Series(conf["lower Apple"], index=test.index)
upper_series = pd.Series(conf["upper Apple"], index=test.index)

# Plot results
plt.figure(figsize=(12,5), dpi=200)
plt.plot(train, label='Training Data', color='blue')
plt.plot(test, label='Actual Test Data', color='orange')
plt.plot(fc_series, label='Forecasted Data', color='green')
plt.fill_between(test.index, lower_series, upper_series, color='pink', alpha=0.15)

plt.title('Apple - Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# ### sarima_model1(Simple) predicts an upward trend in prices for the test data while matches the actual test data.

# %% [markdown]
# ## 6. Model Evaluation

# %% [markdown]
# ### 6.1 Simple Model-1 (sarima_model1)

# %%
# Get predictions
pred = sarima_model1.get_prediction(start='2018-10-01', end='2023-09-28').predicted_mean

# Ensure indices match for MAPE calculation
train_pred = pred.loc[train.index]
test_pred = pred.loc[test.index]

# To evaluate the model
from sklearn.metrics import mean_absolute_percentage_error

mape_train = mean_absolute_percentage_error(train, train_pred)
mape_test = mean_absolute_percentage_error(test, test_pred)

print(f'Model Mean Absolute Percentage Error on training data is {mape_train*100:.2f}%')
print(f'Model Mean Absolute Percentage Error on testing data is {mape_test*100:.2f}%')
# Out:
# Model Mean Absolute Percentage Error on training data is 1.82%
# Model Mean Absolute Percentage Error on testing data is 1.30%

# %% [markdown]
# ### 6.2 Comprehensive Model-2 (sarima_model2)

# %%
# Get predictions
pred = sarima_model2.get_prediction(start='2018-10-01', end='2023-09-28').predicted_mean

# Ensure indices match for MAPE calculation
train_pred = pred.loc[train.index]
test_pred = pred.loc[test.index]

# To evaluate the model
from sklearn.metrics import mean_absolute_percentage_error

mape_train = mean_absolute_percentage_error(train, train_pred)
mape_test = mean_absolute_percentage_error(test, test_pred)

print(f'Model Mean Absolute Percentage Error on training data is {mape_train*100:.2f}%')
print(f'Model Mean Absolute Percentage Error on testing data is {mape_test*100:.2f}%')
# Out:
# Model Mean Absolute Percentage Error on training data is 1.97%
# Model Mean Absolute Percentage Error on testing data is 1.53%

# %% [markdown]
# ### 6.3 ARIMA Model (arima_model, p,d,q = 0,1,2)

# %%
# Get predictions
pred = arima_model.get_prediction(start='2018-10-01', end='2023-09-28').predicted_mean

# Ensure indices match for MAPE calculation
train_pred = pred.loc[train.index]
test_pred = pred.loc[test.index]

# To evaluate the model
from sklearn.metrics import mean_absolute_percentage_error

mape_train = mean_absolute_percentage_error(train, train_pred)
mape_test = mean_absolute_percentage_error(test, test_pred)

print(f'Model Mean Absolute Percentage Error on training data is {mape_train*100:.2f}%')
print(f'Model Mean Absolute Percentage Error on testing data is {mape_test*100:.2f}%')
# Out:
# Model Mean Absolute Percentage Error on training data is 1.64%
# Model Mean Absolute Percentage Error on testing data is 1.28%

# %% [markdown]
# ### Verdict:
#
# ### Among the time series forecasting models tested in this assignment, the ARIMA model performs the best in terms of prediction accuracy based on the MAPE metric, achieving the lowest MAPE on both the training and testing data.
# ### However, the ARIMA model may not be suitable for forecasting the stock data in this assignment, as the data exhibits seasonality, which ARIMA does not account for effectively.
# ### ARIMA model forecasted a horizontal price line which is unrealistic.
# ### Therefore, the best forecasting model is SARIMA_Model1 (Simple verison).

# %% [markdown]
# ## Model Improvement to be presented at the end of DBS jupyter file.
